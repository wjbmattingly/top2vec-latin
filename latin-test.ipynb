# %%
from top2vec import Top2Vec

# %%
with open("./data/latin.txt", "r") as f:
    lines = f.read().splitlines()
len(lines)
# Out:
# 15556

# %%
model = Top2Vec(lines)
# Out:
# 2022-05-31 09:18:07,742 - top2vec - INFO - Pre-processing documents for training
# 2022-05-31 09:18:08,622 - top2vec - INFO - Creating joint document/word embedding
# 2022-05-31 09:18:28,839 - top2vec - INFO - Creating lower dimension embedding of documents
# 2022-05-31 09:18:42,973 - top2vec - INFO - Finding dense areas of documents
# 2022-05-31 09:18:43,485 - top2vec - INFO - Finding topics

# %%
model.get_num_topics()
# Out:
# 20

# %%
documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=48, num_docs=5)
for doc, score, doc_id in zip(documents, document_scores, document_ids):
    print(f"Document: {doc_id}, Score: {score}")
    print("-----------")
    print(doc)
    print("-----------")
    print()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11220\2936344444.py in <module>
# ----> 1 documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=48, num_docs=5)
#       2 for doc, score, doc_id in zip(documents, document_scores, document_ids):
#       3     print(f"Document: {doc_id}, Score: {score}")
#       4     print("-----------")
#       5     print(doc)
#
# ~\anaconda3\envs\top2vec\lib\site-packages\top2vec\Top2Vec.py in search_documents_by_topic(self, topic_num, num_docs, return_documents, reduced)
#    2310         else:
#    2311
# -> 2312             self._validate_topic_num(topic_num, reduced)
#    2313             self._validate_topic_search(topic_num, num_docs, reduced)
#    2314
#
# ~\anaconda3\envs\top2vec\lib\site-packages\top2vec\Top2Vec.py in _validate_topic_num(self, topic_num, reduced)
#    1173             topic_count = len(self.topic_vectors) - 1
#    1174             if topic_num > topic_count:
# -> 1175                 raise ValueError(f"Invalid topic number: valid original topics numbers are 0 to {topic_count}.")
#    1176
#    1177     def _validate_topic_search(self, topic_num, num_docs, reduced):
#
# ValueError: Invalid topic number: valid original topics numbers are 0 to 19.
