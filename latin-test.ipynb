# %%
from top2vec import Top2Vec

# %%
with open("./data/latin.txt", "r") as f:
    lines = f.read().splitlines()
len(lines)
# Out:
# 15556

# %%
model = Top2Vec(lines)
# Out:
# 2022-05-31 09:18:07,742 - top2vec - INFO - Pre-processing documents for training
# 2022-05-31 09:18:08,622 - top2vec - INFO - Creating joint document/word embedding
# 2022-05-31 09:18:28,839 - top2vec - INFO - Creating lower dimension embedding of documents
# 2022-05-31 09:18:42,973 - top2vec - INFO - Finding dense areas of documents
# 2022-05-31 09:18:43,485 - top2vec - INFO - Finding topics

# %%
model.get_num_topics()
# Out:
# 20

# %%
documents, document_scores, document_ids = model.search_documents_by_topic(topic_num=1, num_docs=10)
for doc, score, doc_id in zip(documents, document_scores, document_ids):
    print(f"Document: {doc_id}, Score: {score}")
    print("-----------")
    print(doc)
    print("-----------")
    print()
# Out:
# Document: 2109, Score: 0.9923712015151978
# -----------
# Tum interrex contione advocata , "Quod bonum , faustum felixque sit " inquit , "Quirites , regem create ita patribus visum est .
# -----------
#
# Document: 7787, Score: 0.9859423637390137
# -----------
# Creati censores C. Sulpicius Camerinus Sp. Postumius Regillensis , coeptaque iam res morte Postumi , quia collegam suffici censori religio erat , interpellata est .
# -----------
#
# Document: 12637, Score: 0.9826635122299194
# -----------
# Cum urbem ui cepissent captamque diripuissent , Carthaginem inde petunt , atque omnem agrum circa depopulati postremo tecta quoque coniuncta muro portisque incenderunt .
# -----------
#
# Document: 10272, Score: 0.9792735576629639
# -----------
# sed equites Romani praevecti per obliqua campi cum se fugientibus obtulissent , omisso ad castra itinere montes petunt ;
# -----------
#
# Document: 13443, Score: 0.9786378145217896
# -----------
# Ipse a Casilino Caiatiam petit atque inde Volturno amni traiecto per agrum Saticulanum Trebianumque super Suessulam per montes Nolam pervenit .
# -----------
#
# Document: 11845, Score: 0.9786283373832703
# -----------
# Itaque armis repente arreptis , in eum ipsum agrum impetu facto tantum terroris ac tumultus fecerunt ut non agrestis modo multitudo sed ipsi triumviri Romani , qui ad agrum venerant adsignandum , diffisi Placentiae moenibus Mutinam confugerint , C. Lutatius , C. Servilius , M. Annius .
# -----------
#
# Document: 3521, Score: 0.9784036874771118
# -----------
# Per secessionem plebis Sp. Cassius et Postumius Cominius consulatum inierunt .
# -----------
#
# Document: 5596, Score: 0.978016197681427
# -----------
# An esse ulla maior aut insignitior contumelia potest quam partem civitatis velut contaminatam indignam conubio haberi ?
# -----------
#
# Document: 1279, Score: 0.9779955148696899
# -----------
# Qui horum quid acerbissime crudelissimeque fecerat , is et vir et civis optimus habebatur .
# -----------
#
# Document: 5425, Score: 0.9758722186088562
# -----------
# Vocis verborumque quantum voletis ingerent , et criminum in principes et legum aliarum super alias ut contionum ;
# -----------
